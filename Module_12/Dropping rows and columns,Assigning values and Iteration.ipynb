# %% [markdown]
# ## Dropping rows and columns,Assigning values and Iteration

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("./student_data.csv")
# df = df.set_index('StudentID')
df.head()
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001       Alif Rahman                  85.0             85.0
# 1    PH1002     Fatima Akhter                  92.0             92.0
# 2    PH1003     Imran Hossain                  88.0             88.0
# 3    PH1004  Jannatul Ferdous                  78.0             78.0
# 4    PH1005       Kamal Uddin                   NaN              NaN
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 0          88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 1           NaN      In Progress     2024-01-20  Ms. Salma  Chattogram
# 2          85.0        Completed     2024-02-10  Mr. Karim       Dhaka
# 3          82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# 4          95.0      In Progress     2024-03-05  Mr. Karim  Chattogram

# %%
# df.drop('PH1001',inplace=True)
# df.head()

# %%
# df.drop('Instructor',axis=1, inplace=True)
# df.head()

# %%
df.loc[1,'Python Marks'] = 90
df.loc[2,'CompletionStatus'] = 'Completed' 
df.head()
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001       Alif Rahman                  85.0             85.0
# 1    PH1002     Fatima Akhter                  92.0             92.0
# 2    PH1003     Imran Hossain                  88.0             88.0
# 3    PH1004  Jannatul Ferdous                  78.0             78.0
# 4    PH1005       Kamal Uddin                   NaN              NaN
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 0          88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 1          90.0      In Progress     2024-01-20  Ms. Salma  Chattogram
# 2          85.0        Completed     2024-02-10  Mr. Karim       Dhaka
# 3          82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# 4          95.0      In Progress     2024-03-05  Mr. Karim  Chattogram

# %%
df.loc[1:3,'Python Marks']+=1
df.head()
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001       Alif Rahman                  85.0             85.0
# 1    PH1002     Fatima Akhter                  92.0             92.0
# 2    PH1003     Imran Hossain                  88.0             88.0
# 3    PH1004  Jannatul Ferdous                  78.0             78.0
# 4    PH1005       Kamal Uddin                   NaN              NaN
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 0          88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 1          91.0      In Progress     2024-01-20  Ms. Salma  Chattogram
# 2          86.0        Completed     2024-02-10  Mr. Karim       Dhaka
# 3          83.0        Completed     2024-02-12  Ms. Salma      Sylhet
# 4          95.0      In Progress     2024-03-05  Mr. Karim  Chattogram

# %%
x = 0 
for i, series in df.iterrows():
    print(f"{i} : {series}")
    if x == 3 :
        break
    x = x + 1
# Out:
# 0 : StudentID                    PH1001
# FullName                Alif Rahman
# Data Structure Marks           85.0
# Algorithm Marks                85.0
# Python Marks                   88.0
# CompletionStatus          Completed
# EnrollmentDate           2024-01-15
# Instructor                Mr. Karim
# Location                      Dhaka
# Name: 0, dtype: object
# 1 : StudentID                      PH1002
# FullName                Fatima Akhter
# Data Structure Marks             92.0
# Algorithm Marks                  92.0
# Python Marks                     91.0
# CompletionStatus          In Progress
# EnrollmentDate             2024-01-20
# Instructor                  Ms. Salma
# Location                   Chattogram
# Name: 1, dtype: object
# 2 : StudentID                      PH1003
# FullName                Imran Hossain
# Data Structure Marks             88.0
# Algorithm Marks                  88.0
# Python Marks                     86.0
# CompletionStatus            Completed
# EnrollmentDate             2024-02-10
# Instructor                  Mr. Karim
# Location                        Dhaka
# Name: 2, dtype: object
# 3 : StudentID                         PH1004
# FullName                Jannatul Ferdous
# Data Structure Marks                78.0
# Algorithm Marks                     78.0
# Python Marks                        83.0
# CompletionStatus               Completed
# EnrollmentDate                2024-02-12
# Instructor                     Ms. Salma
# Location                          Sylhet
# Name: 3, dtype: object

# %%
x = 0 
for i in df.itertuples():
    print(i)
    if x == 3 :
        break
    x = x + 1
# Out:
# Pandas(Index=0, StudentID='PH1001', FullName='Alif Rahman', _3=85.0, _4=85.0, _5=88.0, CompletionStatus='Completed', EnrollmentDate='2024-01-15', Instructor='Mr. Karim', Location='Dhaka')
# Pandas(Index=1, StudentID='PH1002', FullName='Fatima Akhter', _3=92.0, _4=92.0, _5=91.0, CompletionStatus='In Progress', EnrollmentDate='2024-01-20', Instructor='Ms. Salma', Location='Chattogram')
# Pandas(Index=2, StudentID='PH1003', FullName='Imran Hossain', _3=88.0, _4=88.0, _5=86.0, CompletionStatus='Completed', EnrollmentDate='2024-02-10', Instructor='Mr. Karim', Location='Dhaka')
# Pandas(Index=3, StudentID='PH1004', FullName='Jannatul Ferdous', _3=78.0, _4=78.0, _5=83.0, CompletionStatus='Completed', EnrollmentDate='2024-02-12', Instructor='Ms. Salma', Location='Sylhet')

# %% [markdown]
# ## Sorting a DF

# %%
df.head()
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001       Alif Rahman                  85.0             85.0
# 1    PH1002     Fatima Akhter                  92.0             92.0
# 2    PH1003     Imran Hossain                  88.0             88.0
# 3    PH1004  Jannatul Ferdous                  78.0             78.0
# 4    PH1005       Kamal Uddin                   NaN              NaN
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 0          88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 1          91.0      In Progress     2024-01-20  Ms. Salma  Chattogram
# 2          86.0        Completed     2024-02-10  Mr. Karim       Dhaka
# 3          83.0        Completed     2024-02-12  Ms. Salma      Sylhet
# 4          95.0      In Progress     2024-03-05  Mr. Karim  Chattogram

# %%
df.sort_values('Data Structure Marks', ascending=False).head()
# Out:
#    StudentID       FullName  Data Structure Marks  Algorithm Marks  \
# 15    PH1016   Ziaur Rahman                  94.0             94.0
# 1     PH1002  Fatima Akhter                  92.0             92.0
# 16    PH1017    Afsana Mimi                  90.0             90.0
# 9     PH1010   Priya Sharma                  89.0             89.0
# 17    PH1018    Babul Ahmed                  88.0             88.0
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 15           NaN      In Progress     2024-08-21  Ms. Salma  Chattogram
# 1           91.0      In Progress     2024-01-20  Ms. Salma  Chattogram
# 16          93.0        Completed     2025-09-01  Mr. Karim       Dhaka
# 9           88.0        Completed     2024-05-20  Ms. Salma      Sylhet
# 17          85.0        Completed     2025-09-05  Ms. Salma      Sylhet

# %%
df.sort_values(['Data Structure Marks','Algorithm Marks','Python Marks'], ascending=False).head()
# Out:
#    StudentID       FullName  Data Structure Marks  Algorithm Marks  \
# 15    PH1016   Ziaur Rahman                  94.0             94.0
# 1     PH1002  Fatima Akhter                  92.0             92.0
# 16    PH1017    Afsana Mimi                  90.0             90.0
# 9     PH1010   Priya Sharma                  89.0             89.0
# 2     PH1003  Imran Hossain                  88.0             88.0
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 15           NaN      In Progress     2024-08-21  Ms. Salma  Chattogram
# 1           91.0      In Progress     2024-01-20  Ms. Salma  Chattogram
# 16          93.0        Completed     2025-09-01  Mr. Karim       Dhaka
# 9           88.0        Completed     2024-05-20  Ms. Salma      Sylhet
# 2           86.0        Completed     2024-02-10  Mr. Karim       Dhaka

# %% [markdown]
# ## Filtering Data based on condition

# %%
not_started = df.loc[df["CompletionStatus"]=="Not Started"]
not_started
# Out:
#    StudentID      FullName  Data Structure Marks  Algorithm Marks  \
# 13    PH1014    Urmi Akter                   NaN              NaN
# 18    PH1019  Faria Rahman                   NaN              NaN
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 13           NaN      Not Started     2024-07-09  Ms. Salma    Rajshahi
# 18           NaN      Not Started     2025-09-15  Mr. David  Chattogram
