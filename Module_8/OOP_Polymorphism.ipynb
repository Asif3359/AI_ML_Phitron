# %%
# OOP Polymorphism
class Phone :
    # constructure 
    def __init__(self,model,battery,camera, battery_percentage=100):
        self.model = model
        self.battery = battery
        self.camera = camera
        self.battery_percentage = battery_percentage
    # methods 
    def charge(self , hour):
        if self.battery_percentage >=100 :
            print(f"charhge completed")
        else :
            self.battery_percentage += hour 
            print(f"charhge completed by {hour} hr")
    def capture(self, total_photo):
        if (self.battery_percentage <= 0 ) :
            print("No Photo")
        else:
            self.battery_percentage -= total_photo
            print(f"Photo captured in {self.model}")

class Cooling :
    # constructor
    def __init__(self, cooling_method):
        self.cooling_method = cooling_method
    # methods
    def cooling_on (self):
        print(f"The system is cool by {self.cooling_method}")

# class SmartPhone (Phone) :
#     def __init__(self,model,battery,camera, processor):
#         super().__init__(model,battery,camera)
#         self.processor = processor
#     def charge (self,hour):
#         if self.battery_percentage >=100 :
#             print(f"fast charhge completed")
#         else :
#             self.battery_percentage += hour+1 
#             print(f"fast charhge completed by {hour} hr")
#         super().charge(hour)

class Smart_with_cool(SmartPhone, Cooling):
    def __init__(self,model,battery,camera, processor, cooling_method):
        SmartPhone.__init__(self,model,battery,camera, processor)
        Cooling.__init__(self,cooling_method)

# %%
# Polymorphism

class Camera :
    def __init__(self , name):
        self.name = name
    def captur(self):
        print( f"A photo captured {self.name}")

class SmartPhone(Camera):
    def __init__(self , name, resulation):
        super().__init__(name)
        self.resulation = resulation
    def captur(self):
        print( f"A photo captured by a Phone")

class Dslr(Camera):
    def __init__(self , name, resulation):
        super().__init__(name)
        self.resulation = resulation
    def captur(self):
        print( f"A photo captured by a Dslr")

class Drone(Camera):
    def __init__(self , name, resulation):
        super().__init__(name)
        self.resulation = resulation
    def captur(self):
        print( f"A photo captured by a Drone")


phone = SmartPhone("Apple" , "30 Mg")
dslr = Dslr("Kanon" , "100 Mg")
drone = Drone("K 9" , "40 Mg")

phone.captur()
dslr.captur()
drone.captur()
# Out:
# A photo captured by a Phone
# A photo captured by a Dslr
# A photo captured by a Drone
